# %% [markdown]
# <a href="https://colab.research.google.com/github/putrinahampun/NeuralNetworkArchitecture-ImageNet/blob/main/EfficientNet/Efficientnet_ImageClassificationWithImageNetDataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # EfficientNetB0 Pretrained Model

# %%
# To use efficientnetB0 for classifying 1000 classes of images from imagenet, we can use Imagenet weights
# efficientnetBO => Base model

#  EfficienNetB0 is pretrained model
from tensorflow.keras.applications import EfficientNetB0
model = EfficientNetB0(weights = 'imagenet') #trained on 1000 classes of Imagenet dataset

# %%
model.summary()
# Out:
# Model: "efficientnetb0"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ...
#  input_11 (InputLayer)       [(None, 224, 224, 3)]        0         []
#
#  rescaling_20 (Rescaling)    (None, 224, 224, 3)          0         ['input_11[0][0]']
#
#  normalization_10 (Normaliz  (None, 224, 224, 3)          7         ['rescaling_20[0][0]']
#  ation)
#
#  rescaling_21 (Rescaling)    (None, 224, 224, 3)          0         ['normalization_10[0][0]']
#
#  stem_conv_pad (ZeroPadding  (None, 225, 225, 3)          0         ['rescaling_21[0][0]']
#  2D)
#
#  stem_conv (Conv2D)          (None, 112, 112, 32)         864       ['stem_conv_pad[0][0]']
#
#  stem_bn (BatchNormalizatio  (None, 112, 112, 32)         128       ['stem_conv[0][0]']
#  n)
#
#  stem_activation (Activatio  (None, 112, 112, 32)         0         ['stem_bn[0][0]']
#  n)
#
# ...

# %%
import cv2
import numpy as np
from matplotlib.pyplot import imread
from matplotlib.pyplot import imshow
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.imagenet_utils import decode_predictions
from tensorflow.keras.applications.imagenet_utils import preprocess_input

img_path = 'catcutie.jpg'

# preprocessing
img = cv2.imread(img_path)
img = cv2.resize(img, (224,224)) #resizing the image to 224x244

x = np.expand_dims(img,axis=0)
x = preprocess_input(x)

print("Input image shape:", x.shape)

my_image = imread(img_path)
imshow(my_image)
# Out:
# Input image shape: (1, 224, 224, 3)

# %%
preds = model.predict(x)
print('predicted class:',preds) #probabilities for being in each of the 1000 classes
# Out:
# 1/1 [==============================] - 2s 2s/step
# predicted class: [[1.54446927e-04 8.96226993e-05 4.72791253e-05 8.00689450e-05
#   5.89127012e-05 3.84929968e-04 1.55001137e-04 3.98225093e-05
#   7.01620811e-05 7.69376929e-05 1.15825314e-04 1.49183528e-04
#   6.78476281e-05 1.30959015e-04 2.10086262e-04 4.91626088e-05
#   8.66032497e-05 2.65491632e-04 2.29587851e-04 5.31515689e-05
#   1.48780382e-04 8.44415685e-04 1.83835611e-04 5.33818456e-05
#   3.31257121e-04 7.28363375e-05 2.39606612e-04 5.13006526e-04
#   2.31439830e-04 8.01939677e-05 2.32798135e-04 1.17577503e-04
#   1.44745674e-04 1.11044043e-04 1.06999913e-04 1.49180676e-04
#   3.65777087e-04 3.90124042e-05 9.01289095e-05 4.86980243e-05
#   1.33238165e-04 6.27775880e-05 6.02620021e-05 8.48432755e-05
#   7.25206919e-05 3.31857409e-05 9.34921409e-05 2.99630134e-04
#   2.94039928e-05 1.08591361e-04 6.95589406e-05 5.33447419e-05
#   8.66114278e-05 2.08179685e-04 1.19509757e-04 1.15811890e-04
# ...

# %%
decode_predictions(preds,top=3) #probabilities for being in top of the 3 classes
# Out:
# [[('n02124075', 'Egyptian_cat', 0.34498435),
#   ('n02127052', 'lynx', 0.31309497),
#   ('n02123159', 'tiger_cat', 0.05443741)]]

# %% [markdown]
# # EfficientNetB1 Pretrained Model

# %%
from tensorflow.keras.applications import EfficientNetB1
model = EfficientNetB1(weights='imagenet') #trained on 1000 classes of Imagenet dataset

# %%
# the output shape is => 240,240 means we increase the resolution of the image.
model.summary()
# Out:
# Model: "efficientnetb1"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ...
#  input_12 (InputLayer)       [(None, 240, 240, 3)]        0         []
#
#  rescaling_22 (Rescaling)    (None, 240, 240, 3)          0         ['input_12[0][0]']
#
#  normalization_11 (Normaliz  (None, 240, 240, 3)          7         ['rescaling_22[0][0]']
#  ation)
#
#  rescaling_23 (Rescaling)    (None, 240, 240, 3)          0         ['normalization_11[0][0]']
#
#  stem_conv_pad (ZeroPadding  (None, 241, 241, 3)          0         ['rescaling_23[0][0]']
#  2D)
#
#  stem_conv (Conv2D)          (None, 120, 120, 32)         864       ['stem_conv_pad[0][0]']
#
#  stem_bn (BatchNormalizatio  (None, 120, 120, 32)         128       ['stem_conv[0][0]']
#  n)
#
#  stem_activation (Activatio  (None, 120, 120, 32)         0         ['stem_bn[0][0]']
#  n)
#
# ...

# %%
import cv2
import numpy as np
from matplotlib.pyplot import imread
from matplotlib.pyplot import imshow
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.imagenet_utils import decode_predictions
from tensorflow.keras.applications.imagenet_utils import preprocess_input

img_path = 'catcutie.jpg'

# preprocessing
img = cv2.imread(img_path)
img = cv2.resize(img, (240,240)) #resizing the image to 224x244

x = np.expand_dims(img,axis=0)
x = preprocess_input(x)

print("Input image shape:", x.shape)

my_image = imread(img_path)
imshow(my_image)
# Out:
# Input image shape: (1, 240, 240, 3)

# %%
preds = model.predict(x)
print('predicted class:',preds) #probabilities for being in each of the 1000 classes
# Out:
# 1/1 [==============================] - 3s 3s/step
# predicted class: [[2.25202122e-04 3.47222754e-04 5.02569601e-05 1.24072016e-04
#   2.58024433e-04 1.50168111e-04 1.13140624e-04 1.16970121e-04
#   1.94384062e-04 1.72507411e-04 2.03099757e-04 1.84191624e-04
#   1.91244166e-04 1.24886399e-04 2.08557380e-04 3.19552171e-04
#   4.08714579e-04 3.21371801e-04 2.27418757e-04 7.19359668e-05
#   2.84287671e-04 2.35221567e-04 1.15234121e-04 1.65443576e-04
#   3.58541292e-04 2.21456692e-04 1.53858098e-04 2.15246779e-04
#   2.68794422e-04 8.46456896e-05 3.41292965e-04 2.44742085e-04
#   2.22743547e-04 5.28591991e-05 9.97758980e-05 1.07369240e-04
#   1.37261100e-04 1.92597858e-04 1.37460811e-04 2.81607674e-04
#   2.07196921e-04 8.57302512e-05 1.27373612e-04 1.18844873e-04
#   7.02427715e-05 8.58005878e-05 3.33778851e-04 3.26573121e-04
#   4.06564977e-05 4.89778140e-05 7.74703294e-05 2.26123651e-04
#   1.15037132e-04 1.73072869e-04 9.77554009e-05 3.52646835e-04
# ...

# %%
decode_predictions(preds,top=3) #probabilities for being in top of the 3 classes
# Out:
# [[('n02124075', 'Egyptian_cat', 0.40252492),
#   ('n02123045', 'tabby', 0.08648389),
#   ('n02123159', 'tiger_cat', 0.07208507)]]

# %% [markdown]
# # EfficientNetB2 Pretrained Model

# %%
from tensorflow.keras.applications import EfficientNetB2
model = EfficientNetB2(weights='imagenet') #trained on 1000 classes of Imagenet dataset

# %%
model.summary()
# Out:
# Model: "efficientnetb2"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ...
#  input_13 (InputLayer)       [(None, 260, 260, 3)]        0         []
#
#  rescaling_24 (Rescaling)    (None, 260, 260, 3)          0         ['input_13[0][0]']
#
#  normalization_12 (Normaliz  (None, 260, 260, 3)          7         ['rescaling_24[0][0]']
#  ation)
#
#  rescaling_25 (Rescaling)    (None, 260, 260, 3)          0         ['normalization_12[0][0]']
#
#  stem_conv_pad (ZeroPadding  (None, 261, 261, 3)          0         ['rescaling_25[0][0]']
#  2D)
#
#  stem_conv (Conv2D)          (None, 130, 130, 32)         864       ['stem_conv_pad[0][0]']
#
#  stem_bn (BatchNormalizatio  (None, 130, 130, 32)         128       ['stem_conv[0][0]']
#  n)
#
#  stem_activation (Activatio  (None, 130, 130, 32)         0         ['stem_bn[0][0]']
#  n)
#
# ...

# %%
import cv2
import numpy as np
from matplotlib.pyplot import imread
from matplotlib.pyplot import imshow
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.imagenet_utils import decode_predictions
from tensorflow.keras.applications.imagenet_utils import preprocess_input

img_path = 'catcutie.jpg'

# preprocessing
img = cv2.imread(img_path)
img = cv2.resize(img, (260,260)) #resizing the image to 224x244

x = np.expand_dims(img,axis=0)
x = preprocess_input(x)

print("Input image shape:", x.shape)

my_image = imread(img_path)
imshow(my_image)
# Out:
# Input image shape: (1, 260, 260, 3)

# %%
preds = model.predict(x)
print('predicted class:',preds) #probabilities for being in each of the 1000 classes
# Out:
# 1/1 [==============================] - 4s 4s/step
# predicted class: [[1.98506459e-04 2.42687966e-04 6.63675091e-05 1.58190800e-04
#   5.41041372e-04 1.05812222e-04 3.00313204e-05 4.25372302e-04
#   3.35899676e-04 2.67695345e-04 6.56025659e-05 1.49365223e-04
#   7.85425000e-05 2.74317445e-05 8.95445919e-05 1.86256773e-04
#   4.39149095e-04 2.57703679e-04 1.18678916e-04 4.08321939e-05
#   3.05630238e-04 2.28534453e-04 8.05781019e-05 6.02522778e-05
#   1.12233458e-04 1.77983064e-04 1.84594348e-04 2.03107338e-04
#   1.48912775e-04 1.32482033e-04 8.25797179e-05 1.24562343e-04
#   1.85870653e-04 1.07948072e-04 1.24165614e-04 9.88709944e-05
#   1.93964748e-04 5.77174324e-05 1.17528944e-04 8.01669667e-05
#   6.78892975e-05 7.77715759e-05 2.00252427e-04 3.05671885e-04
#   6.25237662e-05 1.21118828e-04 1.10814770e-04 3.04742396e-04
#   1.63445016e-04 6.63567553e-05 9.31764880e-05 2.18564004e-04
#   1.26738625e-04 1.27686129e-04 9.59107929e-05 1.64304409e-04
# ...

# %%
decode_predictions(preds,top=3) #probabilities for being in top of the 3 classes
# Out:
# [[('n02124075', 'Egyptian_cat', 0.5866411),
#   ('n02123159', 'tiger_cat', 0.089811094),
#   ('n02127052', 'lynx', 0.03911992)]]

# %% [markdown]
# # EfficientNetB3 Pretrained Model

# %%
from tensorflow.keras.applications import EfficientNetB3
model = EfficientNetB3(weights='imagenet') #trained on 1000 classes of Imagenet dataset

# %%
model.summary()
# Out:
# Model: "efficientnetb3"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ...
#  input_14 (InputLayer)       [(None, 300, 300, 3)]        0         []
#
#  rescaling_26 (Rescaling)    (None, 300, 300, 3)          0         ['input_14[0][0]']
#
#  normalization_13 (Normaliz  (None, 300, 300, 3)          7         ['rescaling_26[0][0]']
#  ation)
#
#  rescaling_27 (Rescaling)    (None, 300, 300, 3)          0         ['normalization_13[0][0]']
#
#  stem_conv_pad (ZeroPadding  (None, 301, 301, 3)          0         ['rescaling_27[0][0]']
#  2D)
#
#  stem_conv (Conv2D)          (None, 150, 150, 40)         1080      ['stem_conv_pad[0][0]']
#
#  stem_bn (BatchNormalizatio  (None, 150, 150, 40)         160       ['stem_conv[0][0]']
#  n)
#
#  stem_activation (Activatio  (None, 150, 150, 40)         0         ['stem_bn[0][0]']
#  n)
#
# ...

# %%
import cv2
import numpy as np
from matplotlib.pyplot import imread
from matplotlib.pyplot import imshow
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.imagenet_utils import decode_predictions
from tensorflow.keras.applications.imagenet_utils import preprocess_input

img_path = 'catcutie.jpg'

# preprocessing
img = cv2.imread(img_path)
img = cv2.resize(img, (300,300)) #resizing the image to 224x244

x = np.expand_dims(img,axis=0)
x = preprocess_input(x)

print("Input image shape:", x.shape)

my_image = imread(img_path)
imshow(my_image)
# Out:
# Input image shape: (1, 300, 300, 3)

# %%
preds = model.predict(x)
print('predicted class:',preds) #probabilities for being in each of the 1000 classes
# Out:
# 1/1 [==============================] - 5s 5s/step
# predicted class: [[9.05461711e-05 3.10754986e-04 1.02610480e-04 1.56541850e-04
#   4.86576784e-04 1.74920919e-04 1.45061014e-04 1.57848481e-04
#   1.89643222e-04 2.42715745e-04 1.01159058e-04 1.16277341e-04
#   9.88395477e-05 1.05554958e-04 2.78707885e-04 1.80956573e-04
#   1.39080716e-04 5.29473007e-04 8.75949772e-05 5.68717005e-05
#   1.82939621e-04 1.50764507e-04 1.24696948e-04 6.70607187e-05
#   9.22025138e-05 3.05685331e-04 1.36451272e-04 1.38523945e-04
#   1.32704910e-04 7.87884637e-05 1.12688256e-04 2.12504485e-04
#   1.01894329e-04 1.38368545e-04 1.45581274e-04 1.44505393e-04
#   1.53655841e-04 1.46636623e-04 2.84815003e-04 1.71463544e-04
#   9.18511141e-05 1.64895813e-04 5.67091920e-04 1.39897093e-04
#   1.44227146e-04 5.93925070e-05 2.58205284e-04 1.80011790e-04
#   8.27079130e-05 1.07963977e-04 1.62707773e-04 1.05095125e-04
#   1.15544019e-04 1.16257164e-04 1.33679030e-04 1.20594923e-04
# ...

# %%
decode_predictions(preds,top=3) #probabilities for being in top of the 3 classes
# Out:
# [[('n02124075', 'Egyptian_cat', 0.5445685),
#   ('n02123159', 'tiger_cat', 0.06899508),
#   ('n02127052', 'lynx', 0.0514637)]]

# %% [markdown]
# # EfficientNetB4 Pretrained Model

# %%
from tensorflow.keras.applications import EfficientNetB4
model = EfficientNetB4(weights='imagenet') #trained on 1000 classes of Imagenet dataset

# %%
model.summary()
# Out:
# Model: "efficientnetb4"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ...
#  input_15 (InputLayer)       [(None, 380, 380, 3)]        0         []
#
#  rescaling_28 (Rescaling)    (None, 380, 380, 3)          0         ['input_15[0][0]']
#
#  normalization_14 (Normaliz  (None, 380, 380, 3)          7         ['rescaling_28[0][0]']
#  ation)
#
#  rescaling_29 (Rescaling)    (None, 380, 380, 3)          0         ['normalization_14[0][0]']
#
#  stem_conv_pad (ZeroPadding  (None, 381, 381, 3)          0         ['rescaling_29[0][0]']
#  2D)
#
#  stem_conv (Conv2D)          (None, 190, 190, 48)         1296      ['stem_conv_pad[0][0]']
#
#  stem_bn (BatchNormalizatio  (None, 190, 190, 48)         192       ['stem_conv[0][0]']
#  n)
#
#  stem_activation (Activatio  (None, 190, 190, 48)         0         ['stem_bn[0][0]']
#  n)
#
# ...

# %%
import cv2
import numpy as np
from matplotlib.pyplot import imread
from matplotlib.pyplot import imshow
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.imagenet_utils import decode_predictions
from tensorflow.keras.applications.imagenet_utils import preprocess_input

img_path = 'catcutie.jpg'

# preprocessing
img = cv2.imread(img_path)
img = cv2.resize(img, (380,380)) #resizing the image to 224x244

x = np.expand_dims(img,axis=0)
x = preprocess_input(x)

print("Input image shape:", x.shape)

my_image = imread(img_path)
imshow(my_image)
# Out:
# Input image shape: (1, 380, 380, 3)

# %%
preds = model.predict(x)
print('predicted class:',preds) #probabilities for being in each of the 1000 classes
# Out:
# 1/1 [==============================] - 5s 5s/step
# predicted class: [[1.74478249e-04 3.96423333e-04 8.74034376e-05 1.62101191e-04
#   6.07675815e-04 1.20681980e-04 8.94476470e-05 3.64767388e-04
#   2.60236789e-04 2.09192993e-04 2.69723445e-04 4.32090164e-04
#   2.76177423e-04 1.41304350e-04 6.87248539e-04 2.45717412e-04
#   2.42348484e-04 4.07184794e-04 3.18198698e-04 1.98289286e-04
#   5.96345286e-04 3.82544618e-04 2.00394119e-04 5.04116411e-04
#   1.70575178e-04 4.54825931e-04 1.62747601e-04 2.64006143e-04
#   3.47127148e-04 1.72057509e-04 3.49595066e-04 6.84547005e-04
#   1.89622078e-04 2.52766040e-04 3.41356848e-04 1.32231493e-04
#   3.56314646e-04 2.05968900e-04 2.91998760e-04 4.59707633e-04
#   3.72731447e-04 2.27851255e-04 3.61164508e-04 2.61945621e-04
#   2.13493477e-04 9.54132338e-05 5.07153105e-04 3.16059857e-04
#   1.60826603e-04 2.55132531e-04 3.23875778e-04 3.91595677e-04
#   4.64136596e-04 2.35954503e-04 2.19351365e-04 4.92930994e-04
# ...

# %%
decode_predictions(preds,top=3) #probabilities for being in top of the 3 classes
# Out:
# [[('n02124075', 'Egyptian_cat', 0.32356706),
#   ('n02123159', 'tiger_cat', 0.099936634),
#   ('n02123045', 'tabby', 0.07009715)]]

# %% [markdown]
# # EfficientNetB5 Pretrained Model

# %%
from tensorflow.keras.applications import EfficientNetB5
model = EfficientNetB5(weights='imagenet') #trained on 1000 classes of Imagenet dataset

# %%
model.summary()
# Out:
# Model: "efficientnetb5"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ...
#  input_16 (InputLayer)       [(None, 456, 456, 3)]        0         []
#
#  rescaling_30 (Rescaling)    (None, 456, 456, 3)          0         ['input_16[0][0]']
#
#  normalization_15 (Normaliz  (None, 456, 456, 3)          7         ['rescaling_30[0][0]']
#  ation)
#
#  rescaling_31 (Rescaling)    (None, 456, 456, 3)          0         ['normalization_15[0][0]']
#
#  stem_conv_pad (ZeroPadding  (None, 457, 457, 3)          0         ['rescaling_31[0][0]']
#  2D)
#
#  stem_conv (Conv2D)          (None, 228, 228, 48)         1296      ['stem_conv_pad[0][0]']
#
#  stem_bn (BatchNormalizatio  (None, 228, 228, 48)         192       ['stem_conv[0][0]']
#  n)
#
#  stem_activation (Activatio  (None, 228, 228, 48)         0         ['stem_bn[0][0]']
#  n)
#
# ...

# %%
import cv2
import numpy as np
from matplotlib.pyplot import imread
from matplotlib.pyplot import imshow
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.imagenet_utils import decode_predictions
from tensorflow.keras.applications.imagenet_utils import preprocess_input

img_path = 'catcutie.jpg'

# preprocessing
img = cv2.imread(img_path)
img = cv2.resize(img, (456,456)) #resizing the image to 224x244

x = np.expand_dims(img,axis=0)
x = preprocess_input(x)

print("Input image shape:", x.shape)

my_image = imread(img_path)
imshow(my_image)
# Out:
# Input image shape: (1, 456, 456, 3)

# %%
preds = model.predict(x)
print('predicted class:',preds) #probabilities for being in each of the 1000 classes
# Out:
# 1/1 [==============================] - 6s 6s/step
# predicted class: [[1.03315098e-04 2.51691818e-04 1.03594517e-04 1.78836068e-04
#   5.27505588e-04 2.30305101e-04 8.00565904e-05 2.60146509e-04
#   1.59545642e-04 2.67958530e-04 8.43929156e-05 2.05582342e-04
#   1.56537659e-04 9.58367673e-05 2.41236630e-04 1.44608624e-04
#   1.00491256e-04 3.05322988e-04 1.82366784e-04 9.69142275e-05
#   1.43520636e-04 1.30966102e-04 1.07044740e-04 2.27475379e-04
#   1.69958104e-04 1.41612021e-04 1.20771925e-04 1.83337906e-04
#   2.88317417e-04 1.05632993e-04 1.61079835e-04 2.65414477e-04
#   6.66055639e-05 1.25938415e-04 4.58031660e-04 8.47911215e-05
#   2.12645667e-04 3.33810531e-05 2.62231129e-04 1.36400908e-04
#   7.28451050e-05 4.47453167e-05 1.51751025e-04 5.42309244e-05
#   2.78471940e-04 2.26634453e-04 2.46512209e-04 1.59883013e-04
#   1.85951751e-04 7.94327498e-05 1.54269568e-04 1.98718481e-04
#   2.32319027e-04 1.50515945e-04 1.06625281e-04 2.31183236e-04
# ...

# %%
decode_predictions(preds,top=3) #probabilities for being in top of the 3 classes
# Out:
# [[('n02124075', 'Egyptian_cat', 0.5245501),
#   ('n02123159', 'tiger_cat', 0.17825018),
#   ('n02127052', 'lynx', 0.02218558)]]

# %% [markdown]
# # EfficientNetB6 Pretrained Model

# %%
from tensorflow.keras.applications import EfficientNetB6
model = EfficientNetB6(weights='imagenet') #trained on 1000 classes of Imagenet dataset

# %%
model.summary()

# %%
import cv2
import numpy as np
from matplotlib.pyplot import imread
from matplotlib.pyplot import imshow
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.imagenet_utils import decode_predictions
from tensorflow.keras.applications.imagenet_utils import preprocess_input

img_path = 'catcutie.jpg'

# preprocessing
img = cv2.imread(img_path)
img = cv2.resize(img, (528,528)) #resizing the image to 224x244

x = np.expand_dims(img,axis=0)
x = preprocess_input(x)

print("Input image shape:", x.shape)

my_image = imread(img_path)
imshow(my_image)
# Out:
# Input image shape: (1, 528, 528, 3)

# %%
preds = model.predict(x)
print('predicted class:',preds) #probabilities for being in each of the 1000 classes
# Out:
# 1/1 [==============================] - 7s 7s/step
# predicted class: [[1.73286768e-04 2.82034220e-04 8.93477554e-05 2.13056846e-04
#   4.30522719e-04 2.13874198e-04 2.00627561e-04 1.62575059e-04
#   1.03772305e-04 2.65731214e-04 1.32107001e-04 1.85758647e-04
#   2.25169817e-04 1.50550695e-04 3.65231826e-04 2.37517015e-04
#   1.84503879e-04 1.96485227e-04 3.49410489e-04 1.45629092e-04
#   1.94907465e-04 1.68136306e-04 2.20633097e-04 1.29479566e-04
#   1.43005149e-04 2.56405125e-04 1.48490391e-04 2.67711555e-04
#   2.10495942e-04 1.92504041e-04 2.26424396e-04 2.71171069e-04
#   1.01869839e-04 2.32293445e-04 3.67596134e-04 1.10279885e-04
#   2.05776058e-04 1.60621727e-04 1.82140822e-04 1.75015608e-04
#   2.09808219e-04 9.32973708e-05 2.98667757e-04 1.27225634e-04
#   1.43141471e-04 1.66822691e-04 2.25674172e-04 1.83349461e-04
#   1.18382581e-04 1.90540479e-04 1.90772844e-04 1.19189259e-04
#   3.57151323e-04 2.43374816e-04 3.29424336e-04 4.02781239e-04
# ...

# %%
decode_predictions(preds,top=3) #probabilities for being in top of the 3 classes
# Out:
# [[('n02124075', 'Egyptian_cat', 0.43081704),
#   ('n02123159', 'tiger_cat', 0.19100305),
#   ('n02127052', 'lynx', 0.048210192)]]

# %% [markdown]
# # EfficienNetB7 Pretrained Model

# %%
from tensorflow.keras.applications import EfficientNetB7
model = EfficientNetB7(weights='imagenet') #trained on 1000 classes of Imagenet dataset

# %%
model.summary()
# Out:
# Model: "efficientnetb7"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ...
#  input_18 (InputLayer)       [(None, 600, 600, 3)]        0         []
#
#  rescaling_34 (Rescaling)    (None, 600, 600, 3)          0         ['input_18[0][0]']
#
#  normalization_17 (Normaliz  (None, 600, 600, 3)          7         ['rescaling_34[0][0]']
#  ation)
#
#  rescaling_35 (Rescaling)    (None, 600, 600, 3)          0         ['normalization_17[0][0]']
#
#  stem_conv_pad (ZeroPadding  (None, 601, 601, 3)          0         ['rescaling_35[0][0]']
#  2D)
#
#  stem_conv (Conv2D)          (None, 300, 300, 64)         1728      ['stem_conv_pad[0][0]']
#
#  stem_bn (BatchNormalizatio  (None, 300, 300, 64)         256       ['stem_conv[0][0]']
#  n)
#
#  stem_activation (Activatio  (None, 300, 300, 64)         0         ['stem_bn[0][0]']
#  n)
#
# ...

# %%
import cv2
import numpy as np
from matplotlib.pyplot import imread
from matplotlib.pyplot import imshow
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.imagenet_utils import decode_predictions
from tensorflow.keras.applications.imagenet_utils import preprocess_input

img_path = 'catcutie.jpg'

# preprocessing
img = cv2.imread(img_path)
img = cv2.resize(img, (600,600)) #resizing the image to 224x244

x = np.expand_dims(img,axis=0)
x = preprocess_input(x)

print("Input image shape:", x.shape)

my_image = imread(img_path)
imshow(my_image)
# Out:
# Input image shape: (1, 600, 600, 3)

# %%
preds = model.predict(x)
print('predicted class:',preds) #probabilities for being in each of the 1000 classes
# Out:
# 1/1 [==============================] - 11s 11s/step
# predicted class: [[1.55853224e-04 3.13493976e-04 1.95774337e-04 2.09618476e-04
#   2.79181200e-04 2.46876007e-04 1.67322549e-04 1.59152245e-04
#   1.96218447e-04 1.58310737e-04 1.78741160e-04 2.04356707e-04
#   2.76172970e-04 1.65437945e-04 2.13212392e-04 1.35973460e-04
#   1.28326516e-04 2.10002952e-04 2.26050106e-04 1.03827617e-04
#   2.57212901e-04 4.02727776e-04 1.75496418e-04 2.22142640e-04
#   2.56638072e-04 1.73764827e-04 9.62268459e-05 2.70354794e-04
#   3.73314339e-04 1.32176225e-04 1.51981279e-04 3.71195667e-04
#   7.34086207e-05 9.35452626e-05 2.25016513e-04 1.25919352e-04
#   2.01945062e-04 1.03785984e-04 1.77670227e-04 1.52029621e-04
#   1.33914800e-04 1.35426555e-04 1.56896320e-04 1.08018794e-04
#   1.90183608e-04 8.02686191e-05 1.66726342e-04 9.59363824e-05
#   1.34078437e-04 1.50399632e-04 2.02944764e-04 1.36854520e-04
#   1.56078881e-04 1.74702393e-04 7.28206069e-05 2.93265330e-04
# ...

# %%
decode_predictions(preds,top=3) #probabilities for being in top of the 3 classes
# Out:
# [[('n02124075', 'Egyptian_cat', 0.24926533),
#   ('n02123045', 'tabby', 0.19977373),
#   ('n02123159', 'tiger_cat', 0.19638301)]]

# %% [markdown]
# ## Kesimpulan:
# 1. Hasil Training tiap model:
#
#   *   EfficientNetB0 => probabilitas tertinggi: 0.344 (Egyptian_cat)
#   *   EfficientNetB1 => probabilitas tertinggi: 0.402 (Egyptian_cat)
#   *   EfficientNetB2 => probabilitas tertinggi: 0.586 (Egyptian_cat)
#   *   EfficientNetB3 => probabilitas tertinggi: 0.544 (Egyptian_cat)
#   *   EfficientNetB4 => probabilitas tertinggi: 0.323 (Egyptian_cat)
#   *   EfficientNetB5 => probabilitas tertinggi: 0.524 (Egyptian_cat)
#   *   EfficientNetB6 => probabilitas tertinggi: 0.430 (Egyptian_cat)
#   *   EfficientNetB7 => probabilitas tertinggi: 0.249 (Egyptian_cat)
#
# 2. Gambar yang digunakan memiliki ukuran 250 x 175 pixels. Maka ketika dilakukan resizing pada gambar dengan ukuran persegi (cth: 224 x 224), maka gambar akan kelihatan tidak seimbang ukurannya. Hal ini yang mempengaruhi prediksi model, karena seharusnya, kalau model yang dipakai makin naik, maka akurasi nya harusnya makin akurat.
#
# 3. Maka, sarannya kalau mau langsung menggunakan pretrained model sekaligus, tanpa adanya modifikasi, gunakan data gambar dalam bentuk persegi.
